# %%
import pandas as pd
df = pd.read_csv('../10000_songs.csv')

# %%
df = df.dropna() # remove any NaN values as it blows up serialization
data = df.sample(700).to_dict('records') # Get only 700 records. More records will make it slower to index
len(data)
df.head(15)
# Out:
#      artistId               artistName  \
# 0       46087             Erick Sermon
# 4       46087             Erick Sermon
# 8   138226712                     Fun.
# 43    1419227                  Beyoncé
# 61  260388828                    3OH!3
# 62  348580754           Meghan Trainor
# 67  342826213        Waka Flocka Flame
# 72  278873078               Bruno Mars
# 73    3444975               Buckcherry
# 81  174680978              CeeLo Green
# 84  157749142                DJ Khaled
# 87    1419227                  Beyoncé
# 90   80800060               Fort Minor
# 93  543948286  Macklemore & Ryan Lewis
# 95   14400049              Mark Ronson
#
#                                collectionCensoredName  collectionId  \
# 0                                               Music     298321651
# 4                                               Music     298429528
# 8                                         Some Nights     486040153
# 43                                            BEYONCÉ     780330041
# 61                                               Want     281750061
# 62                             Title (Deluxe Edition)     929825574
# 67       No Hands (feat. Roscoe Dash & Wale) - Single     389062036
# 72                                 Unorthodox Jukebox     573962245
# 73                                                 15     140862914
# 81                           F**k You - Deluxe Single     390849614
# 84  All I Do Is Win (feat. T-Pain, Ludacris, Snoop...     353859769
# 87                                            BEYONCÉ     780330041
# 90                   The Rising Tied (Deluxe Edition)      95787592
# 93                                          The Heist     560097246
# 95                                     Uptown Special     943946661
#
#                                        collectionName  collectionPrice  \
# 0                                               Music             9.99
# 4                                               Music             9.99
# 8                                         Some Nights             9.99
# 43                                            BEYONCÉ            15.99
# 61                                               Want             9.99
# 62                             Title (Deluxe Edition)            12.99
# 67       No Hands (feat. Roscoe Dash & Wale) - Single             1.29
# 72                                 Unorthodox Jukebox            10.99
# 73                                                 15            10.99
# 81                           Fuck You - Deluxe Single             2.99
# 84  All I Do Is Win (feat. T-Pain, Ludacris, Snoop...             1.29
# 87                                            BEYONCÉ            15.99
# 90                   The Rising Tied (Deluxe Edition)            13.99
# 93                                          The Heist             9.99
# 95                                     Uptown Special             9.99
#
#    contentAdvisoryRating country currency  discCount  ...  primaryGenreName  \
# 0               Explicit     USA      USD          1  ...       Hip-Hop/Rap
# 4                  Clean     USA      USD          1  ...       Hip-Hop/Rap
# 8               Explicit     USA      USD          1  ...       Alternative
# 43              Explicit     USA      USD          1  ...               Pop
# 61              Explicit     USA      USD          1  ...       Alternative
# 62              Explicit     USA      USD          1  ...               Pop
# 67              Explicit     USA      USD          1  ...       Hip-Hop/Rap
# 72              Explicit     USA      USD          1  ...               Pop
# 73              Explicit     USA      USD          1  ...         Hard Rock
# 81              Explicit     USA      USD          1  ...          R&B/Soul
# 84              Explicit     USA      USD          1  ...       Hip-Hop/Rap
# 87              Explicit     USA      USD          1  ...               Pop
# 90              Explicit     USA      USD          1  ...       Hip-Hop/Rap
# 93                 Clean     USA      USD          1  ...       Hip-Hop/Rap
# 95              Explicit     USA      USD          1  ...               Pop
#
#              releaseDate                                  trackCensoredName  \
# 0   2001-08-27T12:00:00Z                          Music (feat. Marvin Gaye)
# 4   2001-05-29T07:00:00Z                          Music (feat. Marvin Gaye)
# 8   2012-02-21T08:00:00Z                                        Some Nights
# 43  2013-12-13T08:00:00Z                        Drunk in Love (feat. Jay Z)
# 61  2008-06-01T07:00:00Z                                     Don't Trust Me
# 62  2014-06-30T07:00:00Z                                All About That Bass
# 67  2010-08-17T07:00:00Z                No Hands (feat. Roscoe Dash & Wale)
# 72  2012-12-07T08:00:00Z                                           Treasure
# 73  2005-10-17T07:00:00Z                                        Crazy Bitch
# 81  2010-08-19T07:00:00Z                                           F**k You
# 84  2010-02-08T08:00:00Z  All I Do Is Win (feat. T-Pain, Ludacris, Snoop...
# 87  2013-12-13T08:00:00Z                                          Partition
# 90  2005-09-20T07:00:00Z         Remember the Name (feat. Styles of Beyond)
# 93  2012-08-27T07:00:00Z                           Thrift Shop (feat. Wanz)
# 95  2014-11-10T12:00:00Z                     Uptown Funk (feat. Bruno Mars)
#
#    trackCount trackExplicitness    trackId  \
# 0          16          explicit  298321904
# 4          16           cleaned  298429596
# 8          11          explicit  486040194
# 43         14          explicit  780330308
# 61         12          explicit  281750089
# 62         15          explicit  929825615
# 67          1          explicit  389062076
# 72         10          explicit  573962553
# 73         11          explicit  140862717
# 81          2          explicit  390849615
# 84          1          explicit  353859788
# 87         14          explicit  780330377
# 90         17          explicit   95786277
# 93         15           cleaned  560097550
# 95         11          explicit  943946671
#
#                                             trackName  trackNumber trackPrice  \
# 0                                               Music            4       1.29
# 4                                               Music            4       1.29
# 8                                         Some Nights            2       1.29
# 43                        Drunk in Love (feat. Jay Z)            3       1.29
# 61                                     Don't Trust Me            3       1.29
# 62                                All About That Bass            2       1.29
# 67                No Hands (feat. Roscoe Dash & Wale)            1       1.29
# 72                                           Treasure            4       1.29
# 73                                        Crazy Bitch            7       1.29
# 81                                           Fuck You            1       1.29
# 84  All I Do Is Win (feat. T-Pain, Ludacris, Snoop...            1       1.29
# 87                                          Partition            6       1.29
# 90         Remember the Name (feat. Styles of Beyond)            2       1.29
# 93                           Thrift Shop (feat. Wanz)            3       1.29
# 95                     Uptown Funk (feat. Bruno Mars)            4       1.29
#
#     trackTimeMillis
# 0            223133
# 4            223133
# 8            277040
# 43           323486
# 61           192573
# 62           191489
# 67           262533
# 72           178572
# 73           202720
# 81           222933
# 84           232442
# 87           319466
# 90           230493
# 93           235983
# 95           269658
#
# [15 rows x 24 columns]

# %%
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer('all-MiniLM-L6-v2') # Model to create embeddings

# %%
# create the vector database client
qdrant = QdrantClient(":memory:") # Create in-memory Qdrant instance

# %%
# Create collection to store wines
qdrant.recreate_collection(
    collection_name="top_songs",
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(), # Vector size is defined by used model
        distance=models.Distance.COSINE
    )
)
# Out:
# True

# %%
# vectorize!
qdrant.upload_points(
    collection_name="top_songs",
    points=[
        models.PointStruct(
            id=idx,
            vector=encoder.encode(doc["primaryGenreName"]).tolist(),
            payload=doc,
        ) for idx, doc in enumerate(data) # data is the variable holding all the wines
    ]
)

# %%
user_prompt = "Suggest me an amazing pop Song!"

# %%
# Search time for great tunes!

hits = qdrant.search(
    collection_name="top_songs",
    query_vector=encoder.encode(user_prompt).tolist(),
    limit=3
)
for hit in hits:
  print(hit.payload, "score:", hit.score)
# Out:
# {'artistId': 14400049, 'artistName': 'Mark Ronson', 'collectionCensoredName': 'Uptown Special', 'collectionId': 943946661, 'collectionName': 'Uptown Special', 'collectionPrice': 9.99, 'contentAdvisoryRating': 'Explicit', 'country': 'USA', 'currency': 'USD', 'discCount': 1, 'discNumber': 1, 'isStreamable': True, 'kind': 'song', 'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/d3/c9/c2/d3c9c235-d905-1f5c-ef17-ee2e1c484102/mzaf_8910497199692577423.plus.aac.p.m4a', 'primaryGenreName': 'Pop', 'releaseDate': '2015-01-12T12:00:00Z', 'trackCensoredName': 'Feel Right (feat. Mystikal)', 'trackCount': 11, 'trackExplicitness': 'explicit', 'trackId': 943946669, 'trackName': 'Feel Right (feat. Mystikal)', 'trackNumber': 3, 'trackPrice': 1.29, 'trackTimeMillis': 222550} score: 0.47350481386095533
# {'artistId': 980795202, 'artistName': 'Marshmello & Anne-Marie', 'collectionCensoredName': 'Speak Your Mind', 'collectionId': 1351246855, 'collectionName': 'Speak Your Mind', 'collectionPrice': 9.99, 'contentAdvisoryRating': 'Explicit', 'country': 'USA', 'currency': 'USD', 'discCount': 1, 'discNumber': 1, 'isStreamable': False, 'kind': 'song', 'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview112/v4/26/0c/7d/260c7d98-45d7-765f-1d66-7a7cbdd9c8e9/mzaf_1797022355914043761.plus.aac.p.m4a', 'primaryGenreName': 'Pop', 'releaseDate': '2018-02-09T08:00:00Z', 'trackCensoredName': 'FRIENDS', 'trackCount': 12, 'trackExplicitness': 'explicit', 'trackId': 1351247434, 'trackName': 'FRIENDS', 'trackNumber': 7, 'trackPrice': 1.29, 'trackTimeMillis': 202621} score: 0.47350481386095533
# {'artistId': 979458609, 'artistName': 'Olivia Rodrigo', 'collectionCensoredName': 'GUTS', 'collectionId': 1694386825, 'collectionName': 'GUTS', 'collectionPrice': 9.99, 'contentAdvisoryRating': 'Explicit', 'country': 'USA', 'currency': 'USD', 'discCount': 1, 'discNumber': 1, 'isStreamable': True, 'kind': 'song', 'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview126/v4/eb/c2/e4/ebc2e4fc-2645-d745-46bd-98aa65f146bd/mzaf_5420849966703927014.plus.aac.p.m4a', 'primaryGenreName': 'Pop', 'releaseDate': '2023-06-30T07:00:00Z', 'trackCensoredName': 'vampire', 'trackCount': 12, 'trackExplicitness': 'explicit', 'trackId': 1694386830, 'trackName': 'vampire', 'trackNumber': 3, 'trackPrice': 1.29, 'trackTimeMillis': 219724} score: 0.47350481386095533

# %%
# define a variable to hold the search results
search_results = [hit.payload for hit in hits]

# %%
# avoid parallelism
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
# Now time to connect to the local large language model
from openai import OpenAI
client = OpenAI(
    base_url= "http://127.0.0.1:8080/v1", # This is the location for the local LLM model. Note that v1 is appended to what appears in browser
    api_key = "sk-no-key-required"
)

completion = client.chat.completions.create(
    model="LLaMA_CPP",
    messages=[
        {"role": "system", "content": "You are chatbot, a music lover. Your top priority is to help users find songs and guide them with their requests."},
        {"role": "user", "content": "Suggest for me a great 1990s pop song."},
        {"role": "assistant", "content": str(search_results)}
    ]
)
print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content='I suggest you to listen to "Blinding Lights" by The Weeknd. It\'s a great 1990s pop song with a catchy beat and lyrics that will make you want to dance.', role='assistant', function_call=None, tool_calls=None)
